# %%
import warnings
warnings.filterwarnings('ignore')

from imageai.Detection import ObjectDetection
import os

execution_path = os.getcwd()
print(execution_path)

image_path = os.path.join(execution_path, "test.jpg")
print(image_path)

detector = ObjectDetection()
detector.setModelTypeAsRetinaNet()
detector.setModelPath( os.path.join(execution_path, "resnet50_coco_best_v2.0.1.h5"))
detector.loadModel()


#custom_objects = detector.CustomObjects(person = True, car = False)
#detections = detector.detectCustomObjectsFromImage(input_image = image_path , output_image_path = os.path.join(execution_path, "image_new.png"), custom_objects = custom_objects, minimum_percentage_probability = 30)

detections = detector.detectObjectsFromImage(input_image = image_path, output_image_path = os.path.join(execution_path, "image_new1.png"), minimum_percentage_probability = 30)

for eachObject in detections:
    print(eachObject["name"] + ":" + eachObject["percentage_probability"])
    
    print('--------------------------')
# Out:
# F:\AI_projects\Object_detection
# F:\AI_projects\Object_detection\test.jpg
# tracking <tf.Variable 'Variable_120:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_121:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_122:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_123:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_124:0' shape=(9, 4) dtype=float32> anchors
# apple:35.70191264152527
# --------------------------
# apple:38.37689757347107
# --------------------------
# bowl:49.61654841899872
# --------------------------
# sandwich:34.040796756744385
# --------------------------
# bowl:36.91713213920593
# --------------------------
# person:91.94691181182861
# --------------------------
# person:73.61016273498535
# --------------------------
# person:38.81046175956726
# --------------------------
# laptop:40.59042036533356
# --------------------------
# laptop:90.24316668510437
# ...

# %%
from IPython.display import Image
Image("image_new1.png")

# %%
import warnings
warnings.filterwarnings('ignore')

from imageai.Detection import ObjectDetection
import os

execution_path = os.getcwd()
#print(execution_path)

image_path = os.path.join(execution_path, "new_york.jpeg")
#print(image_path)

detector = ObjectDetection()
detector.setModelTypeAsRetinaNet()
detector.setModelPath( os.path.join(execution_path, "resnet50_coco_best_v2.0.1.h5"))
detector.loadModel()


#custom_objects = detector.CustomObjects(person = True, car = False)
#detections = detector.detectCustomObjectsFromImage(input_image = image_path , output_image_path = os.path.join(execution_path, "image_new.png"), custom_objects = custom_objects, minimum_percentage_probability = 30)

detections, objects_path = detector.detectObjectsFromImage(input_image = image_path, output_image_path = os.path.join(execution_path, "image_new1.png"), minimum_percentage_probability = 30,  extract_detected_objects=True)

for eachObject, eachObjectPath in zip(detections, objects_path):
    print(eachObject["name"] , " : " , eachObject["percentage_probability"])
    print("Object's image saved in " + eachObjectPath)
    print("--------------------------------")
# Out:
# tracking <tf.Variable 'Variable_130:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_131:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_132:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_133:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_134:0' shape=(9, 4) dtype=float32> anchors
# person  :  31.14769756793976
# Object's image saved in F:\AI_projects\Object_detection\image_new1.png-objects\person-1.jpg
# --------------------------------
# person  :  30.88758885860443
# Object's image saved in F:\AI_projects\Object_detection\image_new1.png-objects\person-2.jpg
# --------------------------------
# person  :  33.80168080329895
# Object's image saved in F:\AI_projects\Object_detection\image_new1.png-objects\person-3.jpg
# --------------------------------
# person  :  44.397810101509094
# Object's image saved in F:\AI_projects\Object_detection\image_new1.png-objects\person-4.jpg
# ...
